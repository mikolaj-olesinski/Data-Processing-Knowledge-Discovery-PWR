# %% [markdown]
# ### 272702
# ### mikolaj-olesinski

# %%
from src.utils import Player, Team

team = Team("Test")
team.add_player(
    Player("Lewandowski", "forward", age=35, avg_rating=9.2, goals=25, assists=8)
)
print(team.get_summary())
# Out:
# ('Test', 1, 9.2)
